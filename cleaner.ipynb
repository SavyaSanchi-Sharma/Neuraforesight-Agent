# %%
import pandas as pd
from rdkit import Chem

# %%
drugBankVocab=pd.read_csv("data/drugbank vocabulary.csv")
drugBankVocab
# Out:
#       DrugBank ID     Accession Numbers          Common name           CAS  \
# 0         DB00001  BTD00024 | BIOD00024            Lepirudin   138068-37-8
# 1         DB00002  BTD00071 | BIOD00071            Cetuximab   205923-56-4
# 2         DB00003  BTD00001 | BIOD00001         Dornase alfa   143831-71-4
# 3         DB00004  BTD00084 | BIOD00084  Denileukin diftitox   173146-27-5
# 4         DB00005  BTD00052 | BIOD00052           Etanercept   185243-69-0
# ...           ...                   ...                  ...           ...
# 17425     DB19452                   NaN          Exidavnemab  2438229-02-6
# 17426     DB19453                   NaN  Imciromab pentetate   138660-99-8
# 17427     DB19454                   NaN         Cetyl oleate    22393-86-8
# 17428     DB19455                   NaN   Cetyl myristoleate    64660-84-0
# 17429     DB19456                   NaN   Cetyl palmitoleate    22393-83-5
#
# ...

# %%
drugBankVocab.columns
# Out:
# Index(['DrugBank ID', 'Accession Numbers', 'Common name', 'CAS', 'UNII',
#        'Synonyms', 'Standard InChI Key'],
#       dtype='object')

# %%
supplier = Chem.SDMolSupplier("data/open structures.sdf")
drugBankStructuredata = []
for mol in supplier:
    if mol is None:
        continue   
    props = mol.GetPropsAsDict()
    props = {k: str(v) for k, v in props.items()}  
    props['SMILES'] = Chem.MolToSmiles(mol)
    props['Name'] = mol.GetProp('_Name') if mol.HasProp('_Name') else ''
    drugBankStructuredata.append(props)
drugBankStructuredata = pd.DataFrame(drugBankStructuredata)
# Out:
# [15:40:41] Warning: ambiguous stereochemistry - zero final chiral volume - at atom 36 ignored
# [15:40:41] Explicit valence for atom # 13 Cl, 5, is greater than permitted
# [15:40:41] ERROR: Could not sanitize molecule ending on line 126776
# [15:40:41] ERROR: Explicit valence for atom # 13 Cl, 5, is greater than permitted
# [15:40:41] Explicit valence for atom # 19 O, 3, is greater than permitted
# [15:40:41] ERROR: Could not sanitize molecule ending on line 171722
# [15:40:41] ERROR: Explicit valence for atom # 19 O, 3, is greater than permitted
# [15:40:41] The bonds on one end of an atropisomer are both UP or both DOWN - atoms are: 4 5
# [15:40:42] Explicit valence for atom # 15 O, 3, is greater than permitted
# [15:40:42] ERROR: Could not sanitize molecule ending on line 260017
# [15:40:42] ERROR: Explicit valence for atom # 15 O, 3, is greater than permitted
# [15:40:42] Warning: ambiguous stereochemistry - overlapping neighbors  - at atom 16 ignored
# ...

# %%
drugBankStructuredata
# Out:
#       DRUGBANK_ID               SECONDARY_ACCESSION_NUMBERS  \
# 0         DB00006   BTD00076; EXPT03302; BIOD00076; DB02351
# 1         DB00014                       BTD00113; BIOD00113
# 2         DB00027                       BTD00036; BIOD00036
# 3         DB00035  BTD00112; BTD00061; BIOD00112; BIOD00061
# 4         DB00050            BTD00115; APRD00686; BIOD00115
# ...           ...                                       ...
# 12304     DB19446                                       NaN
# 12305     DB19451                                       NaN
# 12306     DB19454                                       NaN
# 12307     DB19455                                       NaN
# 12308     DB19456                                       NaN
#
#               COMMON_NAME    CAS_NUMBER        UNII  \
# 0             Bivalirudin   128270-60-0  TN9BEX005G
# 1               Goserelin    65807-02-5  0F65R8P09N
# 2            Gramicidin D     1405-97-6  5IE62321P4
# ...

# %%
drugs=pd.read_excel("data/medicines_output_medicines_en.xlsx")
drugs
# Out:
#      Content type:     Medicine  \
# 0              NaN          NaN
# 1              NaN          NaN
# 2              NaN          NaN
# 3              NaN          NaN
# 4              NaN          NaN
# ...            ...          ...
# 2579         Human     Liprolog
# 2580         Human      EchoGen
# 2581         Human    Ecokinase
# 2582         Human     Primavax
# 2583         Human  Pylori-Chek
#
#      Output automatically generated from content on www.ema.europa.eu on:  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2579                                    EMEA/H/C/000143
# 2580                                    EMEA/H/C/000149
# ...
